# %%
from pymoo.algorithms.moo.moda.sms_moda import SMSEMOA_MODA
from pymoo.algorithms.moo.sms import SMSEMOA
from pymoo.algorithms.moo.sms_exact import SMSEMOA_EXACT
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from pymoo.util.reference_direction import UniformReferenceDirectionFactory
from pymoo.optimize import minimize
from pymoo.problems import get_problem
import time
from pymoo.indicators.igd import IGD
from pymoo.util.normalization import normalize
import numpy as np


algos = ['wfg1','wfg2','dtlz1','dtlz2','dtlz4']
no_obs = [10,10,4,4,4]
for i,algo in enumerate(algos):
    for j in range(10):
        n_obj = 2
        problem = get_problem(algo,no_obs[i],n_obj=n_obj)
        pf = problem.pareto_front(ref_dirs = UniformReferenceDirectionFactory(n_obj, n_points=136   ).do())
        algorithm = SMSEMOA_MODA()
        start = time.time()
        res_moda = minimize(problem, algorithm, ('n_gen', 25), seed=j, save_history=True)
        moda_time = time.time() - start
        algorithm = SMSEMOA()
        start = time.time()
        res_approx_moo = minimize(problem, algorithm, ('n_gen', 25), seed=j, save_history=True)
        moo_time = time.time() - start
        algorithm = SMSEMOA_EXACT()
        start = time.time()
        res_exact_moo = minimize(problem, algorithm, ('n_gen', 25), seed=j, save_history=True)
        moo_exact_time = time.time() - start
        
        
        F_all = np.vstack([
            res_moda.F,
            res_approx_moo.F,
            res_exact_moo.F,
            pf
        ])

        F_norm = normalize(F_all)

        n1 = len(res_moda.F)
        n2 = len(res_approx_moo.F)
        n3 = len(res_exact_moo.F)

        F_moda_n = F_norm[:n1]
        F_approx_n = F_norm[n1:n1+n2]
        F_exact_n = F_norm[n1+n2:n1+n2+n3]
        pf_n = F_norm[n1+n2+n3:]

        igd = IGD(pf_n)
        igd_moda = igd(F_moda_n)
        igd_approx = igd(F_approx_n)
        igd_exact = igd(F_exact_n)
        print(f'{moo_exact_time}\t{igd_exact}\t{moo_time}\t{igd_approx}\t{moda_time}\t{igd_moda}\r\n',end = '')
# Out:
# 0.18738293647766113	0.607600414870682	0.48902058601379395	0.5947575947186098	5.508931875228882	0.6131411576414365
# 0.18441295623779297	0.6052303822495898	0.5019304752349854	0.6037303532352372	5.283145427703857	0.5967591765835104
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 24
#      22 algorithm = SMSEMOA_MODA()
#      23 start = time.time()
# ---> 24 res_moda = minimize(problem, algorithm, ('n_gen', 25), seed=j, save_history=True)
#      25 moda_time = time.time() - start
#      26 algorithm = SMSEMOA()
#
# File /mnt/c/Users/kubad/moda/moda/moda/python-wrap/.venv/lib/python3.10/site-packages/pymoo/optimize.py:67, in minimize(problem, algorithm, termination, copy_algorithm, copy_termination, **kwargs)
#      64     algorithm.setup(problem, **kwargs)
#      66 # actually execute the algorithm
# ---> 67 res = algorithm.run()
#      69 # store the deep copied algorithm in the result object
#      70 res.algorithm = algorithm
#
# File /mnt/c/Users/kubad/moda/moda/moda/python-wrap/.venv/lib/python3.10/site-packages/pymoo/core/algorithm.py:133, in Algorithm.run(self)
#     131 def run(self):
#     132     while self.has_next():
# --> 133         self.next()
#     134     return self.result()
#
# File /mnt/c/Users/kubad/moda/moda/moda/python-wrap/.venv/lib/python3.10/site-packages/pymoo/core/algorithm.py:154, in Algorithm.next(self)
#     152 if infills is not None:
#     153     self.evaluator.eval(self.problem, infills, algorithm=self)
# --> 154     self.advance(infills=infills)
#     156 # if the algorithm does not follow the infill-advance scheme just call advance
#     157 else:
#     158     self.advance()
#
# File /mnt/c/Users/kubad/moda/moda/moda/python-wrap/.venv/lib/python3.10/site-packages/pymoo/core/algorithm.py:220, in Algorithm.advance(self, infills, **kwargs)
#     215     self._post_advance()
#     217 else:
#     218
#     219     # call the implementation of the advance method - if the infill is not None
# --> 220     val = self._advance(infills=infills, **kwargs)
#     222     # always advance to the next iteration - except if the algorithm returns False
#     223     if val is None or val:
#
# File /mnt/c/Users/kubad/moda/moda/moda/python-wrap/.venv/lib/python3.10/site-packages/pymoo/algorithms/moo/moda/sms_moda.py:205, in SMSEMOA_MODA._advance(self, infills, **kwargs)
#     201 else:
#     202     pop = self.pop
# --> 205 self.pop = self.survival.do(self.problem, pop, n_survive=self.pop_size, algorithm=self,
#     206                             ideal=ideal, nadir=nadir, random_state=self.random_state, **kwargs)
#
# File /mnt/c/Users/kubad/moda/moda/moda/python-wrap/.venv/lib/python3.10/site-packages/pymoo/util/__init__.py:21, in default_random_state.<locals>.decorator.<locals>.wrapper(random_state, *args, **kwargs)
#      19     seed_to_use = kwargs.pop('seed', default_seed)
#      20     random_state = np.random.default_rng(seed_to_use)
# ---> 21 return func(*args, random_state=random_state, **kwargs)
#
# File /mnt/c/Users/kubad/moda/moda/moda/python-wrap/.venv/lib/python3.10/site-packages/pymoo/core/survival.py:59, in Survival.do(self, problem, pop, n_survive, random_state, return_indices, *args, **kwargs)
#      56         survivors = Population.merge(survivors, pop[infeas[:n_remaining]])
#      58 else:
# ---> 59     survivors = self._do(problem, pop, *args, n_survive=n_survive, random_state=random_state, **kwargs)
#      61 if return_indices:
#      62     H = {}
#
# File /mnt/c/Users/kubad/moda/moda/moda/python-wrap/.venv/lib/python3.10/site-packages/pymoo/algorithms/moo/moda/sms_moda.py:93, in LeastHypervolumeContributionSurvival._do(self, problem, pop, n_survive, ideal, nadir, random_state, *args, **kwargs)
#      90 ds = moda.DataSet(data) # this takes virtually no time compared to Solve
#      92 ds.typeOfOptimization = OptimizationType.maximization
# ---> 93 r = solver.Solve(ds,params) # note: Solve actually allocates and deallocates memory - this is a potential problem for small problems (such as 2-objective); additionally python enforces slow and safe memory management (such
#      94                             # as shared_ptrs) or the use of built-in garbage collector and no memory management at all (something to be considered, shared_ptrs are slow)
#      95 k = r[2] #3 is minimum contributor index (0 is minimum contribution, 1 is maximum contribution, 2 in min ctr idx, 3 is max contr idx, 4 is elapsed time)
#
# KeyboardInterrupt:

# %%
import moda
import matplotlib.pyplot as plt
import numpy as np
data = np.array(
    [[2.92619838, 0.9824502 ]
    [2.92918203, 0.98065699]
    [2.93465479, 0.97180209]
    [2.91876162, 0.98729564]
    [2.90624133, 0.992886  ]
    [2.91252783, 0.99025538]]
    
)


argmax = data.max(axis=0)
data = -data
data = data - np.min(data, axis=0) + 5

plt.scatter(data[:,0], data[:,1])
ds = moda.DataSet(data)


solver = moda.QEHCSolver()
params = moda.QEHCParameters()

r = solver.Solve(ds, params)
r
# Out:
# (4.602561176625386e-08, 0.0, 11, -1, 26518)
